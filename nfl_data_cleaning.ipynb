# %%
import pandas as pd
import numpy as np

# %%
# read in nfl data csv
nfl_data_csv = "data/nfl_scores.csv"
nfl_data = pd.read_csv(nfl_data_csv)
nfl_df = pd.DataFrame(nfl_data)

# %%
nfl_df.head(100)
# Out:
#    schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0         9/2/66             1966             1             False
# 1         9/3/66             1966             1             False
# 2         9/4/66             1966             1             False
# 3         9/9/66             1966             2             False
# 4        9/10/66             1966             1             False
# ..           ...              ...           ...               ...
# 95       11/6/66             1966            10             False
# 96       11/6/66             1966            10             False
# 97       11/6/66             1966             9             False
# 98       11/6/66             1966            10             False
# 99       11/6/66             1966             9             False
#
#               team_home  score_home  score_away            team_away  \
# 0        Miami Dolphins          14          23      Oakland Raiders
# ...

# %%
nfl_df.describe()
# Out:
#        schedule_season    score_home    score_away  spread_favorite  \
# count     12678.000000  12678.000000  12678.000000     10199.000000
# mean       1994.434769     22.364411     19.602776        -5.379498
# std          15.297243     10.565200     10.153315         3.431007
# min        1966.000000      0.000000      0.000000       -26.500000
# 25%        1981.000000     14.000000     13.000000        -7.000000
# 50%        1995.000000     21.000000     20.000000        -4.500000
# 75%        2008.000000     29.000000     27.000000        -3.000000
# max        2019.000000     72.000000     62.000000         0.000000
#
#        weather_temperature  weather_wind_mph
# count         11936.000000       11936.00000
# mean             58.621230           7.85196
# std              15.539348           5.62761
# min              -6.000000           0.00000
# 25%              48.000000           4.00000
# 50%              61.000000           8.00000
# ...

# %%
nfl_df["spread_favorite"].value_counts()
nfl_df["over_under_line"].value_counts()
# Out:
# 41      602
# 42      542
# 44      535
# 43      518
# 37      511
#        ...
# 61.5      1
# 63        1
# 29.5      1
# 63.5      1
# 30.5      1
# Name: over_under_line, Length: 68, dtype: int64
